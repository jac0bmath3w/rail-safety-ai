# %% [markdown]
# <a href="https://colab.research.google.com/github/jac0bmath3w/rail-safety-ai/blob/main/extras/test_ingest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jac0bmath3w/rail-safety-ai.git
# Out:
# fatal: destination path 'rail-safety-ai' already exists and is not an empty directory.

# %%
# !pip install pypdf
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-huggingface
# !pip install llama-index

# %%
# !pip install -U langchain-text-splitters

# %%
import sys
sys.path.append('/content/rail-safety-ai/src')
from ingest import RailDocumentProcessor

# Initialize the 'Staff Level' way
processor = RailDocumentProcessor()
raw_data_path = "/content/rail-safety-ai/data/raw"
all_safety_chunks = processor.process_directory(raw_data_path)

print(f"Total Safety Knowledge Base Chunks: {len(all_safety_chunks)}")
# Out:
# Processing: FRA-HRGC-Handbook-2019.pdf
# Processing: FRA-Track_Structures_CM_2026_Vol_III_Ch1_Railroad_Workplace_Safety_General.pdf
# Processing: FRA-Signal_Train_Control-2012.pdf
# Processing: FRA-HRGC-Compliance Manual 11-8-19 Final.pdf
# Processing: FRA-Hazardous_Materials_Compliance_Manual_01.07.25.pdf
# Total Safety Knowledge Base Chunks: 2633

# %%
all_safety_chunks[0]
# Out:
# 'Highway-Rail Crossing \nHANDBOOK \nThird Edition FOREWORD \nThe Highway-Rail Crossing Handbook, 3rd Edition (Handbook) has been prepared to disseminate \ncurrent practices and requirements for developing engineering treatments for highway-rail grade \ncrossings (referred to herein as “crossings”). The Handbook is intended to provide practitioners \nof all levels of knowledge and experience with critical background information and “noteworthy \npractices” consistent with the 2009 Manual on Uniform Traffic Control Devices for Streets \nand Highways (MUTCD) and more recent guidance developed by recognized subject matter \nexperts. This edition constitutes a substantial update to and revision of the 2007 Handbook and \nefforts have been made to reorganize the contents. This edition includes “hotlinks” to facilitate \nnavigation and access external information available on the web. \nNotice \nThis document is disseminated under the sponsorship of the U.S. Department of'
