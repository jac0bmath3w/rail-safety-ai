# %% [markdown]
# <a href="https://colab.research.google.com/github/jac0bmath3w/rail-safety-ai/blob/main/git_maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jac0bmath3w/rail-safety-ai.git
# %cd rail-safety-ai

# %%
# %ls

# %%
# !git config --global user.email "jac0b.math3w@gmail.com"
# !git config --global user.name "Jacob Mathew"

# %%
from google.colab import userdata
import os


token = userdata.get('GITHUB_TOKEN')
username = "jac0bmath3w"
repo = "rail-safety-ai"

# %%
# !git merge --abort

# !git pull origin main --no-edit

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
username = "jac0bmath3w"
repo = "rail-safety-ai"

# %%
# !git add <>
# !git commit -m ""

# %%
# !git push https://{token}@github.com/{username}/{repo}.git
